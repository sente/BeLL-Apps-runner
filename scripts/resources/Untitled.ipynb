# %%
import pandas

# %%
import json

# %%
df = pandas.read_json('resources.json')

# %%
df.head
# Out:
# <bound method DataFrame.head of         uploadDate Collection  \
# 0     1.395676e+12        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4              NaN        NaN
# 5              NaN        NaN
# 6              NaN        NaN
# 7              NaN        NaN
# 8              NaN        NaN
# 9     1.398783e+12        NaN
# 10             NaN        NaN
# 11             NaN        NaN
# 12             NaN        NaN
# 13    1.397594e+12        NaN
# 14    1.397595e+12        NaN
# 15             NaN        NaN
# 16    1.401727e+12        NaN
# 17    1.401727e+12        NaN
# 18    1.397310e+12        NaN
# 19             NaN        NaN
# 20    1.401732e+12        NaN
# 21    1.401732e+12        NaN
# 22    1.397674e+12        NaN
# 23    1.397675e+12        NaN
# 24    1.397675e+12        NaN
# 25    1.397675e+12        NaN
# 26    1.397311e+12        NaN
# 27    1.397314e+12        NaN
# 28    1.397316e+12        NaN
# ...

# %%
df.head()
# Out:
#      uploadDate Collection              Level            Medium  \
# 0  1.395676e+12        NaN     [Professional]  Audio/Music/Book
# 1           NaN        NaN    [Upper Primary]              Text
# 2           NaN        NaN  [Early Education]              Text
# 3           NaN        NaN    [Lower Primary]              Text
# 4           NaN        NaN    [Lower Primary]              Text
#
#               Publisher                                                Tag  \
# 0                        [cc11a4c42d45448a3448193899aab654, 845ca5617e9...
# 1  africanstorybook.org  [2cb04e36e7836460c98d481f7e9a5076, ebae4ec2179...
# 2    African Storybooks  [2cb04e36e7836460c98d481f7e9a5076, ebae4ec2179...
# 3  africanstorybook.org  [2cb04e36e7836460c98d481f7e9a5076, ebae4ec2179...
# 4  africanstorybook.org  [2cb04e36e7836460c98d481f7e9a5076, ebae4ec2179...
#
#    Year                                       _attachments  \
# 0        {u'002-BobbyDarin-MackTheKnife.mp3': {u'stub':...
# ...

# %%
df['language']
# Out:
# 0        English
# 1        English
# 2        English
# 3        English
# 4        English
# 5        English
# 6            eng
# 7
# 8        English
# 9        English
# 10       Sawhili
# 11       English
# 12       English
# 13       English
# 14       English
# 15       English
# 16        Arabic
# 17        Arabic
# 18        Somali
# 19       English
# 20        Somali
# 21        Somali
# 22       English
# 23       English
# 24       English
# 25       English
# 26       English
# 27       English
# 28       English
# 29       English
#           ...
# 3651     English
# 3652    eng, swa
# 3653         eng
# 3654         eng
# 3655         eng
# 3656     English
# 3657
# 3658         eng
# 3659     English
# 3660     English
# 3661     English
# 3662     English
# 3663     English
# 3664     English
# 3665     English
# 3666     English
# 3667     English
# 3668     English
# 3669     English
# 3670         eng
# 3671     English
# 3672     English
# 3673     English
# ...

# %%
df.language.head()
# Out:
# 0    English
# 1    English
# 2    English
# 3    English
# 4    English
# Name: language, dtype: object

# %%
df.language.description()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-cb11f197d5c1> in <module>()
# ----> 1 df.language.description()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1976                 return self[name]
#    1977             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1978                                  (type(self).__name__, name))
#    1979
#    1980     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'description'

# %%
df.language.mode()
# Out:
# 0    English
# dtype: object

# %%
df.language.unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-633690050a0f> in <module>()
# ----> 1 df.language.unique()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/base.pyc in unique(self)
#     447             return values.unique()
#     448
# --> 449         return unique1d(values)
#     450
#     451     def nunique(self, dropna=True):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/nanops.pyc in unique1d(values)
#     733     else:
#     734         table = _hash.PyObjectHashTable(len(values))
# --> 735         uniques = table.unique(_ensure_object(values))
#     736     return uniques
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.unique (pandas/hashtable.c:13716)()
#
# TypeError: unhashable type: 'list'

# %%
list(df.language)
# Out:
# [u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'eng',
#  u'',
#  u'English',
#  u'English',
#  u'Sawhili',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'Arabic',
#  u'Arabic',
#  u'Somali',
#  u'English',
#  u'Somali',
#  u'Somali',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'eng',
#  u'English',
#  u'English',
#  u'English',
#  u'eng',
#  u'English',
#  u'Spanish',
#  u'',
#  u'Urdu, English',
#  u'English',
#  u'English',
#  u'English',
#  u' English ',
#  u'Somali and English ',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  u'',
#  u'English',
#  u'English',
#  u'Arabic',
#  u'Arabic',
#  u'English',
#  u'English',
#  u'English',
#  u'English',
#  nan,
#  u'English',
# ...

# %%
[x for x in list(df['language']) if isinstance(x,list)]
# Out:
# [[u'eng'], [u'eng'], [u'eng'], [u'eng'], [u'eng'], [u'eng']]

# %%
df.drop?

# %%
df[df.language.len()==1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-5d0f2f8fa278> in <module>()
# ----> 1 df[df.language.len()==1]
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1976                 return self[name]
#    1977             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1978                                  (type(self).__name__, name))
#    1979
#    1980     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'len'

# %%
df.language.apply(tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-9a8fab0da06c> in <module>()
# ----> 1 df.language.apply(tuple)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2047             values = lib.map_infer(values, lib.Timestamp)
#    2048
# -> 2049         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2050         if len(mapped) and isinstance(mapped[0], Series):
#    2051             from pandas.core.frame import DataFrame
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:56990)()
#
# TypeError: 'float' object is not iterable

# %%
df[isinstance(df['language'],list)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-8233d34e2304> in <module>()
# ----> 1 df[isinstance(df['language'],list)]
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1785             return self._getitem_multilevel(key)
#    1786         else:
# -> 1787             return self._getitem_column(key)
#    1788
#    1789     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1792         # get column
#    1793         if self.columns.is_unique:
# -> 1794             return self._get_item_cache(key)
#    1795
#    1796         # duplicate columns & possible reduce dimensionaility
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1077         res = cache.get(item)
# ...

# %%
df['language']
# Out:
# 0        English
# 1        English
# 2        English
# 3        English
# 4        English
# 5        English
# 6            eng
# 7
# 8        English
# 9        English
# 10       Sawhili
# 11       English
# 12       English
# 13       English
# 14       English
# 15       English
# 16        Arabic
# 17        Arabic
# 18        Somali
# 19       English
# 20        Somali
# 21        Somali
# 22       English
# 23       English
# 24       English
# 25       English
# 26       English
# 27       English
# 28       English
# 29       English
#           ...
# 3651     English
# 3652    eng, swa
# 3653         eng
# 3654         eng
# 3655         eng
# 3656     English
# 3657
# 3658         eng
# 3659     English
# 3660     English
# 3661     English
# 3662     English
# 3663     English
# 3664     English
# 3665     English
# 3666     English
# 3667     English
# 3668     English
# 3669     English
# 3670         eng
# 3671     English
# 3672     English
# 3673     English
# ...

# %%
df.type
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16      nation
# 17      nation
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22      nation
# 23      nation
# 24         NaN
# 25      nation
# 26         NaN
# 27         NaN
# 28         NaN
# 29      nation
#          ...
# 3651       NaN
# 3652       NaN
# 3653       NaN
# 3654       NaN
# 3655       NaN
# 3656       NaN
# 3657       NaN
# 3658       NaN
# 3659    nation
# 3660       NaN
# 3661       NaN
# 3662       NaN
# 3663       NaN
# 3664       NaN
# 3665       NaN
# 3666    nation
# 3667    nation
# 3668       NaN
# 3669       NaN
# 3670       NaN
# 3671       NaN
# 3672       NaN
# 3673    nation
# 3674       NaN
# 3675       NaN
# 3676       NaN
# 3677       NaN
# ...

# %%
df.types
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-cc98ec88ee78> in <module>()
# ----> 1 df.types
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1976                 return self[name]
#    1977             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1978                                  (type(self).__name__, name))
#    1979
#    1980     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'types'

# %%
df.head()
# Out:
#      uploadDate Collection              Level            Medium  \
# 0  1.395676e+12        NaN     [Professional]  Audio/Music/Book
# 1           NaN        NaN    [Upper Primary]              Text
# 2           NaN        NaN  [Early Education]              Text
# 3           NaN        NaN    [Lower Primary]              Text
# 4           NaN        NaN    [Lower Primary]              Text
#
#               Publisher                                                Tag  \
# 0                        [cc11a4c42d45448a3448193899aab654, 845ca5617e9...
# 1  africanstorybook.org  [2cb04e36e7836460c98d481f7e9a5076, ebae4ec2179...
# 2    African Storybooks  [2cb04e36e7836460c98d481f7e9a5076, ebae4ec2179...
# 3  africanstorybook.org  [2cb04e36e7836460c98d481f7e9a5076, ebae4ec2179...
# 4  africanstorybook.org  [2cb04e36e7836460c98d481f7e9a5076, ebae4ec2179...
#
#    Year                                       _attachments  \
# 0        {u'002-BobbyDarin-MackTheKnife.mp3': {u'stub':...
# ...

# %%
ll = df['language']

# %%
ll
# Out:
# 0        English
# 1        English
# 2        English
# 3        English
# 4        English
# 5        English
# 6            eng
# 7
# 8        English
# 9        English
# 10       Sawhili
# 11       English
# 12       English
# 13       English
# 14       English
# 15       English
# 16        Arabic
# 17        Arabic
# 18        Somali
# 19       English
# 20        Somali
# 21        Somali
# 22       English
# 23       English
# 24       English
# 25       English
# 26       English
# 27       English
# 28       English
# 29       English
#           ...
# 3651     English
# 3652    eng, swa
# 3653         eng
# 3654         eng
# 3655         eng
# 3656     English
# 3657
# 3658         eng
# 3659     English
# 3660     English
# 3661     English
# 3662     English
# 3663     English
# 3664     English
# 3665     English
# 3666     English
# 3667     English
# 3668     English
# 3669     English
# 3670         eng
# 3671     English
# 3672     English
# 3673     English
# ...

# %%
ll.astype?

# %%
df
# Out:
#         uploadDate Collection  \
# 0     1.395676e+12        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4              NaN        NaN
# 5              NaN        NaN
# 6              NaN        NaN
# 7              NaN        NaN
# 8              NaN        NaN
# 9     1.398783e+12        NaN
# 10             NaN        NaN
# 11             NaN        NaN
# 12             NaN        NaN
# 13    1.397594e+12        NaN
# 14    1.397595e+12        NaN
# 15             NaN        NaN
# 16    1.401727e+12        NaN
# 17    1.401727e+12        NaN
# 18    1.397310e+12        NaN
# 19             NaN        NaN
# 20    1.401732e+12        NaN
# 21    1.401732e+12        NaN
# 22    1.397674e+12        NaN
# 23    1.397675e+12        NaN
# 24    1.397675e+12        NaN
# 25    1.397675e+12        NaN
# 26    1.397311e+12        NaN
# 27    1.397314e+12        NaN
# 28    1.397316e+12        NaN
# 29    1.391204e+12        NaN
# ...

# %%
df.language=df.language.astype(str)

# %%
df.language.unique()
# Out:
# array(['English', 'eng', '', 'Sawhili', 'Arabic', 'Somali', 'Spanish',
#        'Urdu, English', ' English ', 'Somali and English ', 'nan',
#        'Somali and English', 'Eng', 'spa', 'English and Somali', 'Swahili',
#        'som', 'English ', 'English, Spanish', 'French', 'Swahili, English',
#        'Som / Eng', 'English and Nepalese', 'English and Arabic',
#        'english', 'Urdu', 'spanish', 'fre', 'somali',
#        '\xd8\xa7\xd9\x84\xd8\xb9\xd8\xb1\xd8\xa8\xd9\x8a\xd8\xa9',
#        'Somali / English', "[u'eng']", 'french', 'som,English',
#        'javascript', 'eng ', 'Somali ', 'English & Swahili', 'eng, som',
#        'Spanish, English', 'swa', 'eng, all', 'All', 'eng, swa'], dtype=object)

# %%
df.language.count()
# Out:
# 3681

# %%
df.language.hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-c77e605c40b7> in <module>()
# ----> 1 df.language.hist()
#
# /usr/local/lib/python2.7/site-packages/pandas/tools/plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2825         values = self.dropna().values
#    2826
# -> 2827         ax.hist(values, bins=bins, **kwds)
#    2828         ax.grid(grid)
#    2829         axes = np.array([ax])
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    8324             # this will automatically overwrite bins,
#    8325             # so that each histogram uses the same bins
# ...

# %%
df.subject.value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-431c83809a94> in <module>()
# ----> 1 df.subject.value_counts()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/base.pyc in value_counts(self, normalize, sort, ascending, bins, dropna)
#     422         from pandas.tseries.api import DatetimeIndex, PeriodIndex
#     423         result = value_counts(self, sort=sort, ascending=ascending,
# --> 424                               normalize=normalize, bins=bins, dropna=dropna)
#     425
#     426         if isinstance(self, PeriodIndex):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/algorithms.pyc in value_counts(values, sort, ascending, normalize, bins, dropna)
#     243             values = com._ensure_object(values)
#     244             mask = com.isnull(values)
# --> 245             keys, counts = htable.value_count_object(values, mask)
# ...
